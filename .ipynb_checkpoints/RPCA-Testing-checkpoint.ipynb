# %% [markdown]
# # Testing RPCA-PGSG on tree dataset
# Reads in ./data/trees.bin
#
# Writes output to ./results/

# %%
include("./PGSG.jl")
using PGSG
using PyPlot

# %%
##### load data #####
println("load data...")
n,m = 20480, 102;
fid = open("./data/trees.bin","r")
A   = read(fid, UInt8, n*m)
A   = reshape(A, n, m)
close(fid)

A   = A/255

##### set up parameters #####
k   = 10; #number of componets in low rank model

# svd initialization
println("svd initialization...")
UΣV,nconv,niter,nmult,resid = svds(A,nsv=k,tol=1e-12)
U   = diagm(sqrt(UΣV[:S]))*UΣV[:U].';
V   = diagm(sqrt(UΣV[:S]))*UΣV[:V];
for I in eachindex(U)
    U[I] < 0.0 ? U[I] = 0.0 :
    U[I] > 1.0 ? U[I] = 1.0 : continue
end
for I in eachindex(V)
    V[I] < 0.0 ? V[I] = 0.0 :
    V[I] > 1.0 ? V[I] = 1.0 : continue
end

##### apply solver #####
println("start solver...")
T=40
sol, obj, inner_obj, grad_size = RPCA_PF_PGSG(U,V,A,0.1,T);
U, V = sol[1], sol[2];
# Out:
# load data...
# svd initialization...
# start solver...
# Inner loop finished 0.0
# Inner loop finished 0.8795875248791859
# Inner loop finished 1.3538018894223338
# Inner loop finished 1.8003843428205388
# Inner loop finished 2.159086178242723
# Inner loop finished 2.5452324453098925
# Inner loop finished 2.9635677051126965
# Inner loop finished 3.39128308973812
# Inner loop finished 3.8416969199867563
# Inner loop finished 4.354839724793075
# Inner loop finished 4.891103083626795
# Inner loop finished 5.500017147568387
# Inner loop finished 6.181395860937162
# Inner loop finished 6.911664881151647
# Inner loop finished 7.775924855927025
# Inner loop finished 8.708776938936733
# Inner loop finished 9.763421674648827
# Inner loop finished 10.961254611281394
# Inner loop finished 12.212727794398052
# Inner loop finished 13.505948682627798
# Inner loop finished 14.765808551520163
# Inner loop finished 15.743727467580364
# Inner loop finished 16.251294743779077
# Inner loop finished 16.493301438607116
# Inner loop finished 16.134034610943292
# Inner loop finished 15.398139259852769
# Inner loop finished 14.114720071248811
# Inner loop finished 12.220691309265813
# Inner loop finished 10.080067873026927
# Inner loop finished 8.418767258717063
# Inner loop finished 7.109944724075594
# Inner loop finished 6.647002557514118
# Inner loop finished 6.502223305328677
# Inner loop finished 6.4852710993624605
# Inner loop finished 6.432357360207169
# Inner loop finished 6.370605643038553
# Inner loop finished 6.313086840624008
# Inner loop finished 6.383961565424884
# Inner loop finished 6.330364814550856

# %%
plot(1:T-1, obj)
xlabel("Outer Iterations")
ylabel("Objective")
savefig("Outer-ObjectivePlot.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001E8EF080>)

# %%
innerCounts = zeros(T-1)
tots=0
for i in 1:T-1
   tots = tots+i
   innerCounts[i] = tots 
end
plot(innerCounts, obj)
xlabel("Inner Iterations")
ylabel("Objective")
savefig("Inner-ObjectivePlot.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001E959EF0>)

# %%
plot(1:convert(Int64, (T-1)*(T-2)/2), inner_obj)
xlabel("Inner Iterations")
ylabel("Objective")
savefig("Noisy-Inner-ObjectivePlot.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002A28F390>)

# %%
plot(1:T-1, grad_size)
xlabel("Outer Iterations")
ylabel("Subgradient Norm")
savefig("SubgradientPlot.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001F0650F0>)

# %% [markdown]
# # Write output to Results directory

# %%
##### recover S and save data #####
m,n = size(A);
println("recover S...")
L = U.'*V;
r = A - L;
κσ = 0.7;
# κσ = κ;
S = zeros(m,n);
for I in eachindex(S)
    r[I] >  κσ ? S[I] = r[I] - κσ :
    r[I] < -κσ ? S[I] = r[I] + κσ : continue;
end

##### save results #####
println("save data...")
fid = open("./results/trees_PGSG_UV.bin","w");
write(fid,U,V);
close(fid);
fid = open("./results/trees_PGSG_LS.bin","w");
write(fid,L,S);
close(fid);
fid = open("./results/trees_PGSG_R.bin","w");
write(fid,r);
close(fid);
# Out:
# recover S...
# save data...

# %% [markdown]
# # Generate Pictures out of Results directory

# %%
#======= Analysis the Results from RPCA =======#
#using PyPlot

m,n = 20480, 102;
mp,np = 128, 160;

# load data
fid = open("./results/trees_PGSG_LS.bin","r");
L   = read(fid, Float64, m*n);
S   = read(fid, Float64, m*n);
close(fid)
fid = open("./results/trees_PGSG_R.bin","r");
R   = read(fid, Float64, m*n);
close(fid)
L   = reshape(L,m,n);
S   = reshape(S,m,n);
R   = reshape(R,m,n);
P   = copy(S);

id  = [101,102]
L   = L[:,id]
S   = S[:,id]
R   = R[:,id]
P   = P[:,id]

for I in eachindex(L)
    L[I] < 0.0 ? L[I] = 0.0 :
    L[I] > 1.0 ? L[I] = 1.0 : continue
end
for I in eachindex(S)
    S[I] = abs(S[I])
    R[I] = abs(R[I])
    # S[I] == 0.0 || (S[I] = 1.0)
    # R[I] == 0.0 || (R[I] = 1.0)
end

for I in eachindex(P)
    P[I] == 0.0 || (P[I] = 1.0)
end

# plot result

for i in 1:length(id)
    imshow([reshape(L[:,i],mp,np);reshape(R[:,i],mp,np);reshape(P[:,i],mp,np)], cmap="gist_gray");
    axis("off")
    savefig(@sprintf("./results/trees_h%06d.eps",i+2),bbox_inches="tight",transparent=true);
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001F1F5DD8>)

# %%
inner_obj
# Out:
# 741-element Array{Float64,1}:
#  4408.08
#  4405.08
#  4401.52
#  4400.56
#  4395.59
#  4391.43
#  4394.1
#  4388.53
#  4384.72
#  4381.22
#  4384.13
#  4379.76
#  4374.82
#     ⋮
#   221.32
#   221.034
#   219.004
#   220.449
#   225.488
#   221.311
#   219.724
#   217.329
#   217.853
#   222.775
#   219.743
#   219.111
